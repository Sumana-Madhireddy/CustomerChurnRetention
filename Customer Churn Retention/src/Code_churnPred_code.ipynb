# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
data = pd.read_csv("D:/Data Intensive Computing/Project Phase 1/vgollapu_sumanama_chintha_Phase_1/Churndata.csv")
df= pd.DataFrame(data)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No        NaN    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  FEMALE            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7108  5766-ZJYBB    male            0.0      No         No     1.0
# 7109  9798-DRYDS  Female            0.0     Yes        Yes    17.0
# 7110  0562-HKHML    MALE            0.0     Yes        Yes    71.0
# 7111  4801-KFYKL    Male            0.0      No        Yes     8.0
# 7112  9938-ZREHM  Female            0.0     Yes         No    37.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# 1             Yes                No             DSL                  Yes  ...
# 2             Yes                No             DSL                  Yes  ...
# 3              No  No phone service             DSL                  Yes  ...
# 4             Yes                No     Fiber optic                   No  ...
# ...           ...               ...             ...                  ...  ...
# 7108          Yes                No              No  No internet service  ...
# 7109          Yes               Yes             DSL                   No  ...
# 7110          Yes               Yes              No  No internet service  ...
# 7111          Yes                No              No  No internet service  ...
# 7112          Yes               Yes             DSL                   No  ...
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 0                      No                   No                   No
# 1                      No                   No                   No
# 2                      No                   No                   No
# 3                     Yes                   No                   No
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 7108  No internet service  No internet service  No internet service
# 7109                  Yes                   No                   No
# 7110  No internet service  No internet service  No internet service
# 7111  No internet service  No internet service  No internet service
# 7112                  Yes                   No                  Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7108  Month-to-month               No               Mailed check
# 7109        One year              Yes               Mailed check
# 7110        Two year               No    Credit card (automatic)
# 7111  Month-to-month               No  Bank transfer (automatic)
# 7112        One year               No               Mailed check
#
#      MonthlyCharges TotalCharges  Churn  Count
# 0             29.85        29.85     No      0
# 1             56.95      1889.50     No      1
# 2             53.85       108.15    Yes      2
# 3             42.30      1840.75     No      3
# 4             70.70       151.65    Yes      4
# ...             ...          ...    ...    ...
# 7108          19.40        19.40    Yes   2526
# 7109          61.95      1070.70     No   2198
# 7110          23.90      1626.40     No   5897
# 7111          19.45       159.20     No   5162
# 7112          72.10      2658.40     No   3925
#
# [7113 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7113 entries, 0 to 7112
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7102 non-null   object
#  1   gender            7073 non-null   object
#  2   SeniorCitizen     7102 non-null   float64
#  3   Partner           7102 non-null   object
#  4   Dependents        7070 non-null   object
#  5   tenure            7102 non-null   float64
#  6   PhoneService      7102 non-null   object
#  7   MultipleLines     7102 non-null   object
#  8   InternetService   7102 non-null   object
#  9   OnlineSecurity    7102 non-null   object
#  10  OnlineBackup      7102 non-null   object
#  11  DeviceProtection  7102 non-null   object
#  12  TechSupport       7102 non-null   object
#  13  StreamingTV       7102 non-null   object
#  14  StreamingMovies   7102 non-null   object
#  15  Contract          7058 non-null   object
#  16  PaperlessBilling  7056 non-null   object
#  17  PaymentMethod     7102 non-null   object
#  18  MonthlyCharges    7053 non-null   float64
#  19  TotalCharges      7102 non-null   float64
#  20  Churn             7102 non-null   object
#  21  Count             7113 non-null   int64
# dtypes: float64(4), int64(1), object(17)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (7113, 22)

# %%
df.info()
print(df['MonthlyCharges'].max())
print(df['MonthlyCharges'].min())

print(df['TotalCharges'].max())
print(df['TotalCharges'].min())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7113 entries, 0 to 7112
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7102 non-null   object
#  1   gender            7073 non-null   object
#  2   SeniorCitizen     7102 non-null   float64
#  3   Partner           7102 non-null   object
#  4   Dependents        7070 non-null   object
#  5   tenure            7102 non-null   float64
#  6   PhoneService      7102 non-null   object
#  7   MultipleLines     7102 non-null   object
#  8   InternetService   7102 non-null   object
#  9   OnlineSecurity    7102 non-null   object
#  10  OnlineBackup      7102 non-null   object
#  11  DeviceProtection  7102 non-null   object
#  12  TechSupport       7102 non-null   object
#  13  StreamingTV       7102 non-null   object
#  14  StreamingMovies   7102 non-null   object
#  15  Contract          7058 non-null   object
#  16  PaperlessBilling  7056 non-null   object
#  17  PaymentMethod     7102 non-null   object
#  18  MonthlyCharges    7053 non-null   float64
#  19  TotalCharges      7102 non-null   float64
#  20  Churn             7102 non-null   object
#  21  Count             7113 non-null   int64
# dtypes: float64(4), int64(1), object(17)
# memory usage: 1.2+ MB
# 219.0
# 18.25
# 8684.8
# 18.8

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'Count'], dtype=object)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen       float64
# Partner              object
# Dependents           object
# tenure              float64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# Count                 int64
# dtype: object

# %%
# Checking Duplicate values

Duplic_rows=df[df.duplicated()]
Duplic_rows
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7043  7554-NEWDD    Male            0.0      No         No    10.0
# 7044  9069-LGEUL    MALE            0.0     Yes         No    23.0
# 7045  1964-SVLEA    Male            0.0      No         No    20.0
# 7046  5696-QURRL    Male            0.0      No         No     1.0
# 7047  7673-BQGKU  Female            0.0     Yes        Yes    69.0
# ...          ...     ...            ...     ...        ...     ...
# 7108  5766-ZJYBB    male            0.0      No         No     1.0
# 7109  9798-DRYDS  Female            0.0     Yes        Yes    17.0
# 7110  0562-HKHML    MALE            0.0     Yes        Yes    71.0
# 7111  4801-KFYKL    Male            0.0      No        Yes     8.0
# 7112  9938-ZREHM  Female            0.0     Yes         No    37.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 7043          Yes           Yes              No  No internet service  ...
# 7044          Yes            No             DSL                  Yes  ...
# 7045          Yes            No              No  No internet service  ...
# 7046          Yes            No             DSL                   No  ...
# 7047          Yes            No              No  No internet service  ...
# ...           ...           ...             ...                  ...  ...
# 7108          Yes            No              No  No internet service  ...
# 7109          Yes           Yes             DSL                   No  ...
# 7110          Yes           Yes              No  No internet service  ...
# 7111          Yes            No              No  No internet service  ...
# 7112          Yes           Yes             DSL                   No  ...
#
#               TechSupport          StreamingTV      StreamingMovies  \
# 7043  No internet service  No internet service  No internet service
# 7044                   No                   No                  Yes
# 7045  No internet service  No internet service  No internet service
# 7046                   No                   No                   No
# 7047  No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7108  No internet service  No internet service  No internet service
# 7109                  Yes                   No                   No
# 7110  No internet service  No internet service  No internet service
# 7111  No internet service  No internet service  No internet service
# 7112                  Yes                   No                  Yes
#
#             Contract PaperlessBilling              PaymentMethod  \
# 7043        Two year               No  Bank transfer (automatic)
# 7044  Month-to-month              Yes  Bank transfer (automatic)
# 7045        One year              Yes               Mailed check
# 7046  Month-to-month              Yes               Mailed check
# 7047        Two year               No  Bank transfer (automatic)
# ...              ...              ...                        ...
# 7108  Month-to-month               No               Mailed check
# 7109        One year              Yes               Mailed check
# 7110        Two year               No    Credit card (automatic)
# 7111  Month-to-month               No  Bank transfer (automatic)
# 7112        One year               No               Mailed check
#
#      MonthlyCharges TotalCharges  Churn  Count
# 7043          25.70       251.60     No    159
# 7044          59.95      1406.00     No    366
# 7045          19.70       415.90     No   1933
# 7046          45.05        45.05    Yes   2887
# 7047          20.15      1337.50     No   5273
# ...             ...          ...    ...    ...
# 7108          19.40        19.40    Yes   2526
# 7109          61.95      1070.70     No   2198
# 7110          23.90      1626.40     No   5897
# 7111          19.45       159.20     No   5162
# 7112          72.10      2658.40     No   3925
#
# [70 rows x 22 columns]

# %% [markdown]
# Dropping the duplicates

# %%
# Drop the Duplicate rows

df=df.drop_duplicates()
df
# Out:
#        customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0      7590-VHVEG  Female            0.0     Yes         No     1.0
# 1      5575-GNVDE    Male            0.0      No        NaN    34.0
# 2      3668-QPYBK    Male            0.0      No         No     2.0
# 3      7795-CFOCW    Male            0.0      No         No    45.0
# 4      9237-HQITU  FEMALE            0.0      No         No     2.0
# ...           ...     ...            ...     ...        ...     ...
# 7038   6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH*  female            0.0     Yes        Yes    72.0
# 7040   4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041   8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042   3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  Count
# 0              Electronic check          29.85        29.85     No      0
# 1                  Mailed check          56.95      1889.50     No      1
# 2                  Mailed check          53.85       108.15    Yes      2
# 3     Bank transfer (automatic)          42.30      1840.75     No      3
# 4              Electronic check          70.70       151.65    Yes      4
# ...                         ...            ...          ...    ...    ...
# 7038               Mailed check          84.80      1990.50     No   7038
# 7039    Credit card (automatic)         103.20      7362.90     No   7039
# 7040           Electronic check          29.60       346.45     No   7040
# 7041               Mailed check          74.40       306.60    Yes   7041
# 7042  Bank transfer (automatic)         105.65      6844.50     No   7042
#
# [7043 rows x 22 columns]

# %% [markdown]
# Dropping unwanted columns

# %%
df=df.drop('Count',axis=1)
df
# Out:
#        customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0      7590-VHVEG  Female            0.0     Yes         No     1.0
# 1      5575-GNVDE    Male            0.0      No        NaN    34.0
# 2      3668-QPYBK    Male            0.0      No         No     2.0
# 3      7795-CFOCW    Male            0.0      No         No    45.0
# 4      9237-HQITU  FEMALE            0.0      No         No     2.0
# ...           ...     ...            ...     ...        ...     ...
# 7038   6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH*  female            0.0     Yes        Yes    72.0
# 7040   4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041   8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042   3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95       1889.50
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [7043 rows x 21 columns]

# %%
# Null value row count

row_null = df.isnull().sum()
row_null
# Out:
# customerID          11
# gender              40
# SeniorCitizen       11
# Partner             11
# Dependents          42
# tenure              11
# PhoneService        11
# MultipleLines       11
# InternetService     11
# OnlineSecurity      11
# OnlineBackup        11
# DeviceProtection    11
# TechSupport         11
# StreamingTV         11
# StreamingMovies     11
# Contract            55
# PaperlessBilling    56
# PaymentMethod       11
# MonthlyCharges      60
# TotalCharges        11
# Churn               11
# dtype: int64

# %% [markdown]
# Dropping the rows which have Null values in it.

# %%
# Dropping null value rows

df=df.dropna()
df
# Out:
#        customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0      7590-VHVEG  Female            0.0     Yes         No     1.0
# 2      3668-QPYBK    Male            0.0      No         No     2.0
# 3      7795-CFOCW    Male            0.0      No         No    45.0
# 4      9237-HQITU  FEMALE            0.0      No         No     2.0
# 5      9305-CDSKC  Female            0.0      No         No     8.0
# ...           ...     ...            ...     ...        ...     ...
# 7038   6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH*  female            0.0     Yes        Yes    72.0
# 7040   4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041   8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042   3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# 5             Yes               Yes     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# 5                 Yes          No         Yes             Yes  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# 5                 Yes           Electronic check          99.65        820.50
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 2       Yes
# 3        No
# 4       Yes
# 5       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [6831 rows x 21 columns]

# %% [markdown]
# Removing the Special Characters except ‘– ‘.

# %%
special_chars = ['*','.', '&', '\\', '\/', ';', '\(','\)','_']

for i in special_chars:
    df["customerID"] = df["customerID"].str.strip(i)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\304969819.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["customerID"] = df["customerID"].str.strip(i)

# %% [markdown]
# Converting the gender column to Pascal's case for uniformity.

# %%
df['gender']=df['gender'].str.title()
df
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\3081920130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender']=df['gender'].str.title()
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# 5     9305-CDSKC  Female            0.0      No         No     8.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# 5             Yes               Yes     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# 5                 Yes          No         Yes             Yes  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# 5                 Yes           Electronic check          99.65        820.50
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80       1990.50
# 7039              Yes    Credit card (automatic)         103.20       7362.90
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40        306.60
# 7042              Yes  Bank transfer (automatic)         105.65       6844.50
#
#       Churn
# 0        No
# 2       Yes
# 3        No
# 4       Yes
# 5       Yes
# ...     ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
#
# [6831 rows x 21 columns]

# %% [markdown]
# Box plot for Tenure column to find the outliers

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(df['tenure'])
plt.xlabel('Tenure')
plt.ylabel('Values')
plt.title('Box Plot for tenure')
plt.show()

# %% [markdown]
# Filling Outliers with Mean

# %%
mean_tenure = (df[(df['tenure'] <= 75)]['tenure']).mean()
print(int(mean_tenure))
df.loc[(df['tenure'] >= 75), 'tenure'] = int(mean_tenure)
# Out:
# 32

# %% [markdown]
# After the outlier treatment

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(df['tenure'])
plt.xlabel('Tenure')
plt.ylabel('Values')
plt.title('Box Plot for tenure')
plt.show()

# %% [markdown]
# . Checking Outliers for Monthly charges and filling it with Mean.

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(df['MonthlyCharges'])
plt.xlabel('Monthly Charges')
plt.ylabel('Values')
plt.title('Box Plot for Monthly Charges')
plt.show()

# %%
mean_MonthlyCharges = (df[(df['MonthlyCharges'] <= 120)]['MonthlyCharges']).mean()
print(int(mean_MonthlyCharges))
df.loc[(df['MonthlyCharges'] >= 120), 'MonthlyCharges'] = int(mean_MonthlyCharges)
# Out:
# 64

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(df['MonthlyCharges'])
plt.xlabel('Monthly Charges')
plt.ylabel('Values')
plt.title('Box Plot for Monthly Charges')
plt.show()

# %% [markdown]
# Normalization of the numerical column to get the values between 0 and 1

# %%
# Normalization for columns with numirical values

df['tenure']=(df['tenure']-min(df['tenure']))/(max(df['tenure'])-min(df['tenure']))

df['MonthlyCharges']=(df['MonthlyCharges']-min(df['MonthlyCharges']))/(max(df['MonthlyCharges'])-min(df['MonthlyCharges']))

df['TotalCharges']=(df['TotalCharges']-min(df['TotalCharges']))/(max(df['TotalCharges'])-min(df['TotalCharges']))
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\3870379934.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tenure']=(df['tenure']-min(df['tenure']))/(max(df['tenure'])-min(df['tenure']))
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\3870379934.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MonthlyCharges']=(df['MonthlyCharges']-min(df['MonthlyCharges']))/(max(df['MonthlyCharges'])-min(df['MonthlyCharges']))
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\3870379934.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalCharges']=(df['TotalCharges']-min(df['TotalCharges']))/(max(df['TotalCharges'])-min(df['TotalCharges']))

# %% [markdown]
# One hot encoding for String (Categorical) columns

# %%
df['customerID'] = df['customerID'].astype('category').cat.codes
df['gender'] = df['gender'].astype('category').cat.codes
df['Partner'] = df['Partner'].astype('category').cat.codes
df['Dependents'] = df['Dependents'].astype('category').cat.codes
df['PhoneService'] = df['PhoneService'].astype('category').cat.codes
df['MultipleLines'] = df['MultipleLines'].astype('category').cat.codes
df['InternetService'] = df['InternetService'].astype('category').cat.codes
df['OnlineSecurity'] = df['OnlineSecurity'].astype('category').cat.codes
df['OnlineBackup'] = df['OnlineBackup'].astype('category').cat.codes
df['DeviceProtection'] = df['DeviceProtection'].astype('category').cat.codes
df['TechSupport'] = df['TechSupport'].astype('category').cat.codes
df['StreamingTV'] = df['StreamingTV'].astype('category').cat.codes
df['StreamingMovies'] = df['StreamingMovies'].astype('category').cat.codes
df['Contract'] = df['Contract'].astype('category').cat.codes
df['PaperlessBilling'] = df['PaperlessBilling'].astype('category').cat.codes
df['PaymentMethod'] = df['PaymentMethod'].astype('category').cat.codes
df['Churn'] = df['Churn'].astype('category').cat.codes
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['customerID'] = df['customerID'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender'] = df['gender'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Partner'] = df['Partner'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dependents'] = df['Dependents'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PhoneService'] = df['PhoneService'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MultipleLines'] = df['MultipleLines'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['InternetService'] = df['InternetService'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OnlineSecurity'] = df['OnlineSecurity'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OnlineBackup'] = df['OnlineBackup'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DeviceProtection'] = df['DeviceProtection'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TechSupport'] = df['TechSupport'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['StreamingTV'] = df['StreamingTV'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['StreamingMovies'] = df['StreamingMovies'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Contract'] = df['Contract'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PaperlessBilling'] = df['PaperlessBilling'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PaymentMethod'] = df['PaymentMethod'].astype('category').cat.codes
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\777486430.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Churn'] = df['Churn'].astype('category').cat.codes

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0           5198       0            0.0        1           0  0.000000
# 2           2480       1            0.0        0           0  0.014085
# 3           5355       1            0.0        0           0  0.619718
# 4           6304       0            0.0        0           0  0.014085
# 5           6344       0            0.0        0           0  0.098592
# ...          ...     ...            ...      ...         ...       ...
# 7038        4690       1            0.0        1           1  0.323944
# 7039        1477       0            0.0        1           1  1.000000
# 7040        3249       0            0.0        1           1  0.140845
# 7041        5740       1            1.0        1           0  0.042254
# 7042        2151       1            0.0        0           0  0.915493
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0                0              1                0               0  ...
# 2                1              0                0               2  ...
# 3                0              1                0               2  ...
# 4                1              0                1               0  ...
# 5                1              2                1               0  ...
# ...            ...            ...              ...             ...  ...
# 7038             1              2                0               2  ...
# 7039             1              2                1               0  ...
# 7040             0              1                0               2  ...
# 7041             1              2                1               0  ...
# 7042             1              0                1               2  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                    0            0            0                0         0
# 2                    0            0            0                0         0
# 3                    2            2            0                0         1
# 4                    0            0            0                0         0
# 5                    2            0            2                2         0
# ...                ...          ...          ...              ...       ...
# 7038                 2            2            2                2         1
# 7039                 2            0            2                2         1
# 7040                 0            0            0                0         0
# 7041                 0            0            0                0         0
# 7042                 2            2            2                2         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0                    1              2        0.115423      0.001275      0
# 2                    1              3        0.354229      0.010310      1
# 3                    0              0        0.239303      0.210241      0
# 4                    1              2        0.521891      0.015330      1
# 5                    1              2        0.809950      0.092511      1
# ...                ...            ...             ...           ...    ...
# 7038                 1              3        0.662189      0.227521      0
# 7039                 1              1        0.845274      0.847461      0
# 7040                 1              2        0.112935      0.037809      0
# 7041                 1              3        0.558706      0.033210      1
# 7042                 1              0        0.869652      0.787641      0
#
# [6831 rows x 21 columns]

# %%
nullval = df.isnull().sum()
nullval
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
nullval = df.isnull().any(axis=1)
df[nullval]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.shape
# Out:
# (6831, 21)

# %% [markdown]
# ## Plotting Churn count based on Gender to know how many males and females have discontinued or continued their subscription.
# # 0 - Female, 1- Male

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='Churn', data=df)
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('Churn Count based on gender')
plt.legend(title='Churn', labels=['No','Yes'])
plt.show()

# %%
print('Female count for churn = Yes:', df[(df['gender'] == 0) & (df['Churn'] == 1)].shape[0])
print('Female count for churn = No:', df[(df['gender'] == 0) & (df['Churn'] == 0)].shape[0])
print('Male count for churn = Yes:', df[(df['gender'] == 1) & (df['Churn'] == 1)].shape[0])
print('Male count for churn = No:', df[(df['gender'] == 1) & (df['Churn'] == 0)].shape[0])
# Out:
# Female count for churn = Yes: 916
# Female count for churn = No: 2469
# Male count for churn = Yes: 911
# Male count for churn = No: 2535

# %% [markdown]
# ## Plotting Churn count based on SeniorCitizen to know how many SeniorCitizens have discontinued or continued their subscription.
# # 0.0 - Not SeniorCitizen, 1.0 - SeniorCitizen

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.xlabel('SeniorCitizen')
plt.ylabel('Count')
plt.title('Churn Count based on SeniorCitizen')
plt.legend(title='Churn', labels=['No','Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on Dependents to know how many customers with Dependents have discontinued or continued their subscription.
# # 0 - Not having Dependents, 1 - having Dependents

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Dependents', hue='Churn', data=df)
plt.xlabel('Dependents')
plt.ylabel('Count')
plt.title('Churn Count based on Dependents')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on PhoneService to know how many customers choosen  PhoneService have discontinued or continued their subscription.
# # 0 - Not having PhoneService, 1 - having PhoneService

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='PhoneService', hue='Churn', data=df)
plt.xlabel('PhoneService')
plt.ylabel('Count')
plt.title('Churn Count based on PhoneService')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on MultipleLines to know how many customers have MultipleLines have discontinued or continued their subscription.
# # 0 - Not having MultipleLines, 1 - No phone service 2 - having MultipleLines

# %%
churn_multipleLines = df.groupby(['MultipleLines', 'Churn']).size().unstack()
count = churn_multipleLines.sum(axis=1)

churn_percent_yes = (churn_multipleLines[1] / count) * 100
plt.figure(figsize=(10, 6))
plt.pie(churn_percent_yes, labels=churn_percent_yes.index, autopct='%1.1f%%', startangle=140)
plt.title('Churn Percentage for Churn = yes by Payment Method')
plt.show()

churn_percent_no = (churn_multipleLines[0] / count) * 100
plt.figure(figsize=(10, 6))
plt.pie(churn_percent_no, labels=churn_percent_no.index, autopct='%1.1f%%', startangle=140)
plt.title('Churn Percentage for Churn = yes by Payment Method')
plt.show()

# %% [markdown]
# ## Plotting Churn count based on InternetService to know how many customers have InternetService have discontinued or continued their subscription.
# # 0 - DSL, 1 - Fiber optic, 2 - No

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='InternetService', hue='Churn', data=df)
plt.xlabel('InternetService')
plt.ylabel('Count')
plt.title('Churn Count based on InternetService')
plt.legend(title='Churn', labels=['No','Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on OnlineSecurity to know how many customers have OnlineSecurity have discontinued or continued their subscription.
# # 0 - No, 1 - No internet service, 2 - Yes

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='OnlineSecurity', hue='Churn', data=df)
plt.xlabel('OnlineSecurity')
plt.ylabel('Count')
plt.title('Churn Count based on OnlineSecurity')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on OnlineBackup to know how many customers have OnlineBackup have discontinued or continued their subscription.
# # 0 - No, 1 - No internet service, 2 - Yes

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='OnlineBackup', hue='Churn', data=df)
plt.xlabel('OnlineBackup')
plt.ylabel('Count')
plt.title('Churn Count based on OnlineBackup')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on Contract to know how many customers have Contract have discontinued or continued their subscription.
# # 0 - Month-to-month, 1 - One year, 2 - Two year

# %%
sns.countplot(x='Contract', hue='Churn', data=df, order=[0, 1, 2])
plt.title('Kernel frequncy Plot of Churn vs Contract distribution')
plt.xlabel('Contract')
plt.ylabel('frequency')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Plotting Churn count based on PaymentMethod to know how many customers have PaymentMethod have discontinued or continued their subscription.
# # 0- Bank transfer (automatic) ,1- Credit card (automatic), 2 - Electronic check, 3- Mailed check

# %%
churn_payment = df.groupby(['PaymentMethod', 'Churn']).size().unstack()
count = churn_payment.sum(axis=1)

churn_percent_yes = (churn_payment[1] / count) * 100
plt.figure(figsize=(10, 6))
plt.pie(churn_percent_yes, labels=churn_percent_yes.index, autopct='%1.1f%%', startangle=140)
plt.title('Churn Percentage for Churn = yes by Payment Method')
plt.show()

churn_percent_no = (churn_payment[0] / count) * 100
plt.figure(figsize=(10, 6))
plt.pie(churn_percent_no, labels=churn_percent_no.index, autopct='%1.1f%%', startangle=140)
plt.title('Churn Percentage for Churn = no by Payment Method')
plt.show()

# %% [markdown]
# From the first pie chart
#
# we can identify that Electronic Check payment method has a higher percentage of churn ('Yes') relative to others.
# And, Credit Card payment method has a lower percentage of churn ('Yes') compared to others.
#
# Similarly from the second pie chart
#
# we can identify that Credit Card payment method has a higher percentage of churn ('No') relative to others.
# And, Electronic Check payment method has a lower percentage of churn ('No') compared to others.

# %% [markdown]
# ## Plotting Churn count based on Partner to know how many customers who are Partner have discontinued or continued their subscription.
# # 0- No ,1- Yes

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Partner', hue='Churn', data=df)
plt.xlabel('Partner')
plt.ylabel('Count')
plt.title('Churn Count based on Partner')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.show()

# %%
bins = [0, 0.1, 0.17, 0.25, 0.33, 0.41, 0.49, 0.57, 0.65, 0.72, 1]
# labels = ['[0,0.1]', '[0.1,0.17]', '[0.17,0.25]', '[0.25,0.33]', '[0.33,0.41]', '[0.41,0.49]', '[0.49,0.57]', '[0.57,0.65]', '[0.65,0.72]', '[0.72,1]']
labels = ['[0,1)', '[1,17]', '[17,25]', '[25,33]', '[33,41]', '[41,49]', '[49,57]', '[57,65]', '[65,72]', '[72,Inf]']
df['tenure_cat'] = pd.cut(df['tenure'], bins=bins, labels=labels, include_lowest=True)
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_24340\976142459.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tenure_cat'] = pd.cut(df['tenure'], bins=bins, labels=labels, include_lowest=True)

# %%
summary_Tenurecat = df.groupby('tenure_cat')[['gender']].describe()
summary_Tenurecat
# Out:
#             gender
#              count      mean       std  min  25%  50%  75%  max
# tenure_cat
# [0,1)       1650.0  0.506667  0.500107  0.0  0.0  1.0  1.0  1.0
# [1,17]       535.0  0.506542  0.500425  0.0  0.0  1.0  1.0  1.0
# [17,25]      429.0  0.484848  0.500354  0.0  0.0  0.0  1.0  1.0
# [25,33]      457.0  0.536105  0.499241  0.0  0.0  1.0  1.0  1.0
# [33,41]      407.0  0.508600  0.500541  0.0  0.0  1.0  1.0  1.0
# [41,49]      434.0  0.509217  0.500492  0.0  0.0  1.0  1.0  1.0
# [49,57]      345.0  0.475362  0.500118  0.0  0.0  0.0  1.0  1.0
# [57,65]      373.0  0.493298  0.500627  0.0  0.0  0.0  1.0  1.0
# [65,72]      326.0  0.487730  0.500618  0.0  0.0  0.0  1.0  1.0
# [72,Inf]    1875.0  0.507200  0.500082  0.0  0.0  1.0  1.0  1.0

# %% [markdown]
# ## Plotting Churn count based on tenure to know how many customers have discontinued or continued their subscription.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='tenure_cat', hue='Churn', data=df)
plt.xlabel('tenure')
plt.ylabel('frequency')
plt.title('Churn Count based on tenure')
plt.legend(title='Churn', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6831 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        6831 non-null   int16
#  1   gender            6831 non-null   int8
#  2   SeniorCitizen     6831 non-null   float64
#  3   Partner           6831 non-null   int8
#  4   Dependents        6831 non-null   int8
#  5   tenure            6831 non-null   float64
#  6   PhoneService      6831 non-null   int8
#  7   MultipleLines     6831 non-null   int8
#  8   InternetService   6831 non-null   int8
#  9   OnlineSecurity    6831 non-null   int8
#  10  OnlineBackup      6831 non-null   int8
#  11  DeviceProtection  6831 non-null   int8
#  12  TechSupport       6831 non-null   int8
#  13  StreamingTV       6831 non-null   int8
#  14  StreamingMovies   6831 non-null   int8
#  15  Contract          6831 non-null   int8
#  16  PaperlessBilling  6831 non-null   int8
#  17  PaymentMethod     6831 non-null   int8
#  18  MonthlyCharges    6831 non-null   float64
#  19  TotalCharges      6831 non-null   float64
#  20  Churn             6831 non-null   int8
#  21  tenure_cat        6831 non-null   category
# dtypes: category(1), float64(4), int16(1), int8(16)
# memory usage: 652.0 KB

# %%
df=df.drop('tenure_cat',axis=1)
corr_mat = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_mat, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Heatmap showing correlation between various features')
plt.show()

# %% [markdown]
# df

# %% [markdown]
# # Project Phase 2

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Methods for calculating performance parameters and drawing visualizations

# %%
def Accuracy(y_true,y_pred):
    return accuracy_score(y_true,y_pred)*100

def recall(y_true,y_pred): 
    return recall_score(y_true, y_pred)

def precision(y_true,y_pred): 
    return precision_score(y_true, y_pred)

def F1_Score(y_true,y_pred):
    return f1_score(y_true, y_pred)

def ConfusionMatrix(y_true,y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",cbar=True)
    plt.title("Confusion Matrix Visulization")
    plt.xlabel('Predicted Values')
    plt.ylabel('True Values')
    plt.show()

def plot_roc_curve(y_true, y_pred):
    false_pos_rate, true_pos_rate, thresholds = roc_curve(y_true, y_pred)
    roc_area_under_curve = auc(false_pos_rate, true_pos_rate)
    plt.figure()
    plt.plot(false_pos_rate, true_pos_rate, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_area_under_curve)
    plt.plot([0, 1], [0, 1], color='red', lw=1, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend(loc="upper left")
    plt.show()

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0           5198       0            0.0        1           0  0.000000
# 2           2480       1            0.0        0           0  0.014085
# 3           5355       1            0.0        0           0  0.619718
# 4           6304       0            0.0        0           0  0.014085
# 5           6344       0            0.0        0           0  0.098592
# ...          ...     ...            ...      ...         ...       ...
# 7038        4690       1            0.0        1           1  0.323944
# 7039        1477       0            0.0        1           1  1.000000
# 7040        3249       0            0.0        1           1  0.140845
# 7041        5740       1            1.0        1           0  0.042254
# 7042        2151       1            0.0        0           0  0.915493
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0                0              1                0               0  ...
# 2                1              0                0               2  ...
# 3                0              1                0               2  ...
# 4                1              0                1               0  ...
# 5                1              2                1               0  ...
# ...            ...            ...              ...             ...  ...
# 7038             1              2                0               2  ...
# 7039             1              2                1               0  ...
# 7040             0              1                0               2  ...
# 7041             1              2                1               0  ...
# 7042             1              0                1               2  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                    0            0            0                0         0
# 2                    0            0            0                0         0
# 3                    2            2            0                0         1
# 4                    0            0            0                0         0
# 5                    2            0            2                2         0
# ...                ...          ...          ...              ...       ...
# 7038                 2            2            2                2         1
# 7039                 2            0            2                2         1
# 7040                 0            0            0                0         0
# 7041                 0            0            0                0         0
# 7042                 2            2            2                2         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0                    1              2        0.115423      0.001275      0
# 2                    1              3        0.354229      0.010310      1
# 3                    0              0        0.239303      0.210241      0
# 4                    1              2        0.521891      0.015330      1
# 5                    1              2        0.809950      0.092511      1
# ...                ...            ...             ...           ...    ...
# 7038                 1              3        0.662189      0.227521      0
# 7039                 1              1        0.845274      0.847461      0
# 7040                 1              2        0.112935      0.037809      0
# 7041                 1              3        0.558706      0.033210      1
# 7042                 1              0        0.869652      0.787641      0
#
# [6831 rows x 21 columns]

# %% [markdown]
# # Splitting the dataset into 70 percent training and 30 percent testing.
# # choosing Churn column as target column for prediction and all other
# # columns as input columns for prediction

# %%
X=df[['gender','MonthlyCharges','PaymentMethod','PaperlessBilling','SeniorCitizen','PhoneService','MultipleLines','TotalCharges']].to_numpy()
Y=df[['Churn']].to_numpy()
split_ratio = 0.7
split= int(split_ratio * len(X))
X_train, X_test = X[:split], X[split:]   
Y_train, Y_test = Y[:split], Y[split:]

# %% [markdown]
# # 1. K Nearest Neighbours Classification Algorithm

# %%
knearest_model = KNeighborsClassifier(n_neighbors=10)
knearest_model.fit(X_train, Y_train.ravel())
knearest_predictions = knearest_model.predict(X_test)
print("Accuracy=",Accuracy(Y_test,knearest_predictions))
print("Recall =",recall(Y_test,knearest_predictions))
print("Precision =",precision(Y_test,knearest_predictions))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,knearest_predictions)
plot_roc_curve(Y_test,knearest_predictions)
# Out:
# Accuracy= 77.3170731707317
# Recall = 0.3915343915343915
# Precision = 0.6491228070175439
# F1 Score = 0.4884488448844885

# %% [markdown]
# # 2. Logistic Regression Classification Algorithm

# %%
logisticreg_model = LogisticRegression(penalty='l2', C=1.0, solver='newton-cg')
logisticreg_model.fit(X_train, Y_train.ravel())
logisticreg_predictions = logisticreg_model.predict(X_test)
print("Accuracy =",Accuracy(Y_test,logisticreg_predictions))
print("Recall =",recall(Y_test,logisticreg_predictions))
print("Precision =",precision(Y_test,logisticreg_predictions))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,logisticreg_predictions)
plot_roc_curve(Y_test,logisticreg_predictions)
# Out:
# Accuracy = 78.04878048780488
# Recall = 0.42504409171075835
# Precision = 0.6602739726027397
# F1 Score = 0.4884488448844885

# %% [markdown]
# # 3.Support Vector Machine Classification Algorithm

# %%
sv_machine_model = SVC(kernel='linear', C=0.01) 
sv_machine_model.fit(X_train, Y_train.ravel())
sv_machine_predictions = sv_machine_model.predict(X_test)
print("Accuracy =",Accuracy(Y_test,sv_machine_predictions))
print("Recall =",recall(Y_test,sv_machine_predictions))
print("Precision =",precision(Y_test,sv_machine_predictions))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,sv_machine_predictions)
plot_roc_curve(Y_test,sv_machine_predictions)
# Out:
# Accuracy = 72.34146341463415
# Recall = 0.0
# Precision = 0.0
# F1 Score = 0.4884488448844885
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 4. Naive Baye's Classification Algorithm

# %%
nb_classifier = MultinomialNB(alpha=1.0)
nb_classifier.fit(X_train, Y_train.ravel())
y_pred_nb = nb_classifier.predict(X_test)
print("Accuracy =",Accuracy(Y_test,y_pred_nb))
print("Recall =",recall(Y_test,y_pred_nb))
print("Precision =",precision_score(Y_test, y_pred_nb, zero_division='warn'))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,y_pred_nb)
plot_roc_curve(Y_test,y_pred_nb)
# Out:
# Accuracy = 72.34146341463415
# Recall = 0.0
# Precision = 0.0
# F1 Score = 0.4884488448844885
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 5. Random Forest Algorithm

# %%
import pickle
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42,max_depth=12)
rf_classifier.fit(X_train, Y_train.ravel())
y_pred_rf = rf_classifier.predict(X_test)
print("Accuracy =",Accuracy(Y_test,y_pred_rf))
print("Recall =",recall(Y_test,y_pred_rf))
print("Precision =",precision(Y_test,y_pred_rf))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,y_pred_rf)
plot_roc_curve(Y_test,y_pred_rf)
pickle.dump(rf_classifier, open( "best_model_rf.p", 'wb' ))
# Out:
# Accuracy = 79.21951219512195
# Recall = 0.49029982363315694
# Precision = 0.6698795180722892
# F1 Score = 0.4884488448844885

# %% [markdown]
# # 6. Gradient boosting Classification Algorithm

# %%
gb_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_classifier.fit(X_train, Y_train.ravel())
y_pred_gb = gb_classifier.predict(X_test)
print("Accuracy =",Accuracy(Y_test,y_pred_gb))
print("Recall =",recall(Y_test,y_pred_gb))
print("Precision =",precision(Y_test,y_pred_gb))
print("F1 Score =",F1_Score(Y_test,knearest_predictions))
ConfusionMatrix(Y_test,y_pred_gb)
plot_roc_curve(Y_test,y_pred_gb)
# Out:
# Accuracy = 78.73170731707317
# Recall = 0.4620811287477954
# Precision = 0.6666666666666666
# F1 Score = 0.4884488448844885
